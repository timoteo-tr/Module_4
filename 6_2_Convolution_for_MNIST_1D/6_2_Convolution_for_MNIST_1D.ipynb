# %% [markdown]
# # **Convolución para MNIST-1D**
#
# Este cuaderno explora una red convolucional 1D para MNIST-1D.
#
# Ejecuta las celdas en orden. En varios lugares verás la palabra "TAREA": sigue esas instrucciones, anticipa qué ocurrirá o escribe el código necesario para completar las funciones.

# %%
# Ejecuta esta celda una vez si necesitas instalar el repositorio MNIST-1D
# !pip install git+https://github.com/greydanus/mnist1d

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# Las entradas y salidas de entrenamiento y prueba están en
# data['x'], data['y'], data['x_test'] y data['y_test']
print("Samples in training set: {}".format(len(data['y'])))
print("Samples in test set: {}".format(len(data['y_test'])))
print("Length of each sample: {}".format(data['x'].shape[-1]))
# Out:
# Successfully loaded data from ./mnist1d_data.pkl
# Samples in training set: 4000
# Samples in test set: 1000
# Length of each sample: 40

# %%
# Carga los datos
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Muestra los tamaños
print("Training data: %d samples (columns), each with %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d samples (columns), each with %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Training data: 4000 samples (columns), each with 40 dimensions (rows)
# Validation data: 1000 samples (columns), each with 40 dimensions (rows)

# %% [markdown]
# Define la red

# %%
# Estos datos tienen 40 dimensiones de entrada y 10 dimensiones de salida
# Las entradas corresponden a los 40 desplazamientos de la plantilla MNIST-1D.
D_i = 40
# Las salidas corresponden a los 10 dígitos
D_o = 10


# TAREA: crea un modelo con las siguientes capas
# 1. Capa convolucional (entrada: longitud 40 y 1 canal; kernel 3; paso 2; padding="valid"; 15 canales de salida)
# 2. ReLU
# 3. Capa convolucional (entrada: longitud 19 y 15 canales; kernel 3; paso 2; padding="valid"; 15 canales de salida)
# 4. ReLU
# 5. Capa convolucional (entrada: longitud 9 y 15 canales; kernel 3; paso 2; padding="valid"; 15 canales de salida)
# 6. ReLU
# 7. Aplanamiento (convierte 4x15) a longitud 60
# 8. Capa lineal (tamaño de entrada = 60, tamaño de salida = 10)
# Documentación útil:
# https://pytorch.org/docs/1.13/generated/torch.nn.Conv1d.html?highlight=conv1d#torch.nn.Conv1d
# https://pytorch.org/docs/stable/generated/torch.nn.Flatten.html
# https://pytorch.org/docs/1.13/generated/torch.nn.Linear.html?highlight=linear#torch.nn.Linear

# TEN EN CUENTA QUE LAS CAPAS CONVOLUCIONALES NECESITAN RECIBIR EL NÚMERO DE CANALES DE ENTRADA COMO PARÁMETRO
# Y NO EL TAMAÑO DE LA ENTRADA.

# Reemplaza la siguiente función:
model = nn.Sequential(
    nn.Conv1d(in_channels=1, out_channels=15, kernel_size=3, stride=2, padding=0),
    nn.ReLU(),
    nn.Conv1d(in_channels=15, out_channels=15, kernel_size=3, stride=2, padding=0),
    nn.ReLU(),
    nn.Conv1d(in_channels=15, out_channels=15, kernel_size=3, stride=2, padding=0),
    nn.ReLU(),
    nn.Flatten(),
    nn.Linear(60, 100))

# %%
# Inicialización de pesos de He
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
# Elige la función de pérdida de entropía cruzada
loss_function = nn.CrossEntropyLoss()
# Construye el optimizador SGD e inicializa la tasa de aprendizaje y el momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# Objeto que reduce la tasa de aprendizaje a la mitad cada 20 épocas
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# Crea los tensores de datos y guárdalos en un DataLoader
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long')).long()
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long')).long()

# Carga los datos en una clase que crea los lotes
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Inicializa los pesos del modelo
model.apply(weights_init)

# Recorre el conjunto de datos n_epoch veces
n_epoch = 100
# Guarda la pérdida y el porcentaje de error en cada época
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # Recorre los lotes
  for i, data in enumerate(data_loader):
    # Recupera entradas y etiquetas de este lote
    x_batch, y_batch = data
    # Reinicia los gradientes de los parámetros
    optimizer.zero_grad()
    # Paso hacia adelante: calcula la salida del modelo
    pred = model(x_batch[:,None,:])
    # Calcula la pérdida
    loss = loss_function(pred, y_batch)
    # Paso hacia atrás
    loss.backward()
    # Actualización SGD
    optimizer.step()

  # Ejecuta todo el conjunto de datos para obtener estadísticas; normalmente no harías esto
  pred_train = model(x_train[:,None,:])
  pred_val = model(x_val[:,None,:])
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, training loss {losses_train[epoch]:.6f}, training error {errors_train[epoch]:3.2f}, validation loss {losses_val[epoch]:.6f}, validation error {errors_val[epoch]:3.2f}')

  # Indica al programador que evalúe si debe actualizar la tasa de aprendizaje
  scheduler.step()

# Grafica los resultados
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='entrenamiento')
ax.plot(errors_val,'b-',label='validación')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.legend()
plt.show()
# Out:
# Epoch     0, training loss 2.290190, training error 85.70, validation loss 2.290245, validation error 85.90
# Epoch     1, training loss 1.660751, training error 66.12, validation loss 1.688067, validation error 67.40
# Epoch     2, training loss 1.466636, training error 56.78, validation loss 1.483018, validation error 58.80
# Epoch     3, training loss 1.326716, training error 54.90, validation loss 1.315069, validation error 56.00
# Epoch     4, training loss 1.303070, training error 53.00, validation loss 1.331331, validation error 55.50
# Epoch     5, training loss 1.253831, training error 51.85, validation loss 1.259087, validation error 52.90
# Epoch     6, training loss 1.203486, training error 48.38, validation loss 1.217824, validation error 51.40
# Epoch     7, training loss 1.215907, training error 48.78, validation loss 1.264170, validation error 50.90
# Epoch     8, training loss 1.049481, training error 41.75, validation loss 1.085375, validation error 45.10
# Epoch     9, training loss 0.988296, training error 39.95, validation loss 1.037250, validation error 40.20
# Epoch    10, training loss 0.885771, training error 35.80, validation loss 0.942759, validation error 39.80
# Epoch    11, training loss 0.798622, training error 31.07, validation loss 0.849382, validation error 34.10
# Epoch    12, training loss 0.752826, training error 28.90, validation loss 0.812409, validation error 31.30
# Epoch    13, training loss 0.660912, training error 26.03, validation loss 0.697346, validation error 28.10
# Epoch    14, training loss 0.664435, training error 26.32, validation loss 0.752842, validation error 30.00
# Epoch    15, training loss 0.540015, training error 20.32, validation loss 0.583206, validation error 23.50
# Epoch    16, training loss 0.522433, training error 19.70, validation loss 0.589444, validation error 21.20
# Epoch    17, training loss 0.506465, training error 19.28, validation loss 0.600121, validation error 24.20
# Epoch    18, training loss 0.438440, training error 15.72, validation loss 0.502710, validation error 18.40
# Epoch    19, training loss 0.453568, training error 17.12, validation loss 0.535108, validation error 20.60
# Epoch    20, training loss 0.369371, training error 13.10, validation loss 0.460054, validation error 16.70
# Epoch    21, training loss 0.344292, training error 12.45, validation loss 0.434622, validation error 16.10
# Epoch    22, training loss 0.320674, training error 11.55, validation loss 0.413820, validation error 14.60
# Epoch    23, training loss 0.307836, training error 11.00, validation loss 0.406413, validation error 15.00
# Epoch    24, training loss 0.332794, training error 12.22, validation loss 0.422648, validation error 15.60
# Epoch    25, training loss 0.291249, training error 10.62, validation loss 0.391299, validation error 15.00
# Epoch    26, training loss 0.287827, training error 10.12, validation loss 0.378842, validation error 13.60
# Epoch    27, training loss 0.260854, training error 8.90, validation loss 0.366987, validation error 12.60
# Epoch    28, training loss 0.292111, training error 10.80, validation loss 0.422770, validation error 16.20
# Epoch    29, training loss 0.254561, training error 8.85, validation loss 0.381331, validation error 13.00
# Epoch    30, training loss 0.278531, training error 10.30, validation loss 0.435428, validation error 15.40
# Epoch    31, training loss 0.257852, training error 9.22, validation loss 0.406550, validation error 14.70
# Epoch    32, training loss 0.246534, training error 8.88, validation loss 0.376554, validation error 13.30
# Epoch    33, training loss 0.236468, training error 8.50, validation loss 0.399731, validation error 14.30
# Epoch    34, training loss 0.223362, training error 7.78, validation loss 0.364547, validation error 13.20
# Epoch    35, training loss 0.218374, training error 7.82, validation loss 0.367259, validation error 13.10
# Epoch    36, training loss 0.235653, training error 8.70, validation loss 0.402272, validation error 14.50
# Epoch    37, training loss 0.218131, training error 7.85, validation loss 0.387788, validation error 14.50
# Epoch    38, training loss 0.285460, training error 10.55, validation loss 0.478418, validation error 16.20
# Epoch    39, training loss 0.257991, training error 9.32, validation loss 0.426319, validation error 14.80
# Epoch    40, training loss 0.185430, training error 6.53, validation loss 0.364468, validation error 12.90
# Epoch    41, training loss 0.179998, training error 6.22, validation loss 0.359289, validation error 12.20
# Epoch    42, training loss 0.175982, training error 6.05, validation loss 0.363890, validation error 12.90
# Epoch    43, training loss 0.176134, training error 5.95, validation loss 0.357003, validation error 12.40
# Epoch    44, training loss 0.179732, training error 6.47, validation loss 0.373575, validation error 13.20
# Epoch    45, training loss 0.181433, training error 6.30, validation loss 0.377655, validation error 12.90
# Epoch    46, training loss 0.164409, training error 5.50, validation loss 0.357540, validation error 12.00
# Epoch    47, training loss 0.168051, training error 6.07, validation loss 0.359149, validation error 12.90
# Epoch    48, training loss 0.160080, training error 5.43, validation loss 0.377124, validation error 12.70
# Epoch    49, training loss 0.163133, training error 5.75, validation loss 0.361827, validation error 12.60
# Epoch    50, training loss 0.157565, training error 5.22, validation loss 0.378726, validation error 12.70
# Epoch    51, training loss 0.149150, training error 4.97, validation loss 0.367240, validation error 12.70
# Epoch    52, training loss 0.162684, training error 5.68, validation loss 0.384025, validation error 12.20
# Epoch    53, training loss 0.150543, training error 5.22, validation loss 0.358416, validation error 11.20
# Epoch    54, training loss 0.156189, training error 5.43, validation loss 0.385798, validation error 12.30
# Epoch    55, training loss 0.160330, training error 5.43, validation loss 0.403116, validation error 13.10
# Epoch    56, training loss 0.143791, training error 4.62, validation loss 0.374730, validation error 11.80
# Epoch    57, training loss 0.137421, training error 4.85, validation loss 0.373159, validation error 12.90
# Epoch    58, training loss 0.143923, training error 5.07, validation loss 0.399433, validation error 12.70
# Epoch    59, training loss 0.139796, training error 4.57, validation loss 0.375268, validation error 11.70
# Epoch    60, training loss 0.128009, training error 4.12, validation loss 0.372130, validation error 12.10
# Epoch    61, training loss 0.126309, training error 4.10, validation loss 0.377322, validation error 12.20
# Epoch    62, training loss 0.129341, training error 4.50, validation loss 0.379646, validation error 12.60
# Epoch    63, training loss 0.125554, training error 4.00, validation loss 0.388080, validation error 12.50
# Epoch    64, training loss 0.129895, training error 4.28, validation loss 0.384412, validation error 12.40
# Epoch    65, training loss 0.125976, training error 4.07, validation loss 0.377954, validation error 12.10
# Epoch    66, training loss 0.123249, training error 3.85, validation loss 0.384611, validation error 12.20
# Epoch    67, training loss 0.119612, training error 3.68, validation loss 0.384122, validation error 11.50
# Epoch    68, training loss 0.121034, training error 4.07, validation loss 0.386765, validation error 12.90
# Epoch    69, training loss 0.124307, training error 3.97, validation loss 0.386665, validation error 12.10
# Epoch    70, training loss 0.119287, training error 3.70, validation loss 0.386064, validation error 11.90
# Epoch    71, training loss 0.117138, training error 3.60, validation loss 0.389996, validation error 12.00
# Epoch    72, training loss 0.115848, training error 3.70, validation loss 0.392047, validation error 11.90
# Epoch    73, training loss 0.120212, training error 3.93, validation loss 0.396866, validation error 12.10
# Epoch    74, training loss 0.114641, training error 3.57, validation loss 0.390284, validation error 12.30
# Epoch    75, training loss 0.114631, training error 3.53, validation loss 0.397098, validation error 11.90
# Epoch    76, training loss 0.120500, training error 4.03, validation loss 0.401556, validation error 12.20
# Epoch    77, training loss 0.114197, training error 3.65, validation loss 0.395758, validation error 12.60
# Epoch    78, training loss 0.115487, training error 4.00, validation loss 0.393997, validation error 12.20
# Epoch    79, training loss 0.111973, training error 3.25, validation loss 0.405810, validation error 12.20
# Epoch    80, training loss 0.107627, training error 3.15, validation loss 0.394451, validation error 11.90
# Epoch    81, training loss 0.109292, training error 3.25, validation loss 0.396911, validation error 11.90
# Epoch    82, training loss 0.108425, training error 3.07, validation loss 0.403218, validation error 12.20
# Epoch    83, training loss 0.106577, training error 3.15, validation loss 0.392112, validation error 12.00
# Epoch    84, training loss 0.107569, training error 3.25, validation loss 0.391679, validation error 11.60
# Epoch    85, training loss 0.106802, training error 3.25, validation loss 0.396360, validation error 12.10
# Epoch    86, training loss 0.105388, training error 3.15, validation loss 0.398141, validation error 12.20
# Epoch    87, training loss 0.105812, training error 3.10, validation loss 0.398363, validation error 11.90
# Epoch    88, training loss 0.104537, training error 3.03, validation loss 0.398547, validation error 12.10
# Epoch    89, training loss 0.106326, training error 3.18, validation loss 0.397158, validation error 12.00
# Epoch    90, training loss 0.104004, training error 3.15, validation loss 0.398947, validation error 11.60
# Epoch    91, training loss 0.103496, training error 2.95, validation loss 0.398828, validation error 11.80
# Epoch    92, training loss 0.104019, training error 3.03, validation loss 0.399305, validation error 12.40
# Epoch    93, training loss 0.102393, training error 3.00, validation loss 0.399416, validation error 12.30
# Epoch    94, training loss 0.106575, training error 3.45, validation loss 0.409020, validation error 12.70
# Epoch    95, training loss 0.103437, training error 2.97, validation loss 0.402871, validation error 12.50
# Epoch    96, training loss 0.101971, training error 2.80, validation loss 0.402117, validation error 11.80
# Epoch    97, training loss 0.101224, training error 2.80, validation loss 0.402922, validation error 11.90
# Epoch    98, training loss 0.102144, training error 2.88, validation loss 0.408329, validation error 12.20
# Epoch    99, training loss 0.100736, training error 2.93, validation loss 0.402128, validation error 12.00
